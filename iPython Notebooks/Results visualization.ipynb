# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pprint
# %matplotlib inline

# %%
import sys
sys.path.append('/home/marco/PycharmProjects/ini_caltech101')
from ini_caltech101.dataset import caltech101

# %% [markdown]
# http://cs231n.github.io/neural-networks-3/
#
# http://cs231n.github.io/assets/nn3/learningrates.jpeg

# %%
import json
def plot(history_json):
    with open(history_json) as data_file:    
        data = json.load(data_file)
    
    fig, axs = plt.subplots(1,2)
    pd.DataFrame(data['loss']).plot(ax=axs[0], figsize=(20,10))
    pd.DataFrame(data['val_loss']).plot(ax=axs[0])

    pd.DataFrame(data['acc']).plot(ax=axs[1], ylim=(0,1))
    pd.DataFrame(data['val_acc']).plot(ax=axs[1], ylim=(0,1))
    return data

# %%
def show_arch(architecture_json):
    with open(architecture_json) as data_file:
        data = json.load(data_file)
    pprint.pprint(data)

# %%
project_path = '/home/marco/PycharmProjects/ini_caltech101/'

# %%
data = plot(project_path + 'results/2015-10-19_19.26.42_history.json')

# %%
show_arch(project_path + 'results/2015-10-19_19.26.42_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 7,
#               u'nb_filter': 128,
#               u'nb_row': 7,
#               u'subsample': [2, 2]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-20_09.56.18_history.json')

# %%
show_arch(project_path + 'results/2015-10-20_09.56.18_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 7,
#               u'nb_filter': 128,
#               u'nb_row': 7,
#               u'subsample': [2, 2]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-20_10.25.49_history.json')

# %%
show_arch(project_path + 'results/2015-10-20_10.25.49_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 7,
#               u'nb_filter': 64,
#               u'nb_row': 7,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-20_10.58.55_history.json')

# %%
show_arch(project_path + 'results/2015-10-20_10.58.55_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 7,
#               u'nb_filter': 64,
#               u'nb_row': 7,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-21_14.53.07_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_14.53.07_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 7,
#               u'nb_filter': 128,
#               u'nb_row': 7,
#               u'subsample': [2, 2]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
# batch normalization
data = plot(project_path + 'results/2015-10-21_15.16.46_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_15.16.46_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 7,
#               u'nb_filter': 128,
#               u'nb_row': 7,
#               u'subsample': [2, 2]},
#              {u'epsilon': 1e-06,
#               u'mode': 0,
#               u'momentum': 0.9,
#               u'name': u'BatchNormalization'},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
# ...

# %%
# batch normalization
data = plot(project_path + 'results/2015-10-21_15.47.25_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_15.47.25_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 7,
#               u'nb_filter': 128,
#               u'nb_row': 7,
#               u'subsample': [2, 2]},
#              {u'epsilon': 1e-06,
#               u'mode': 0,
#               u'momentum': 0.9,
#               u'name': u'BatchNormalization'},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
# ...

# %%
data = plot(project_path + 'results/2015-10-21_16.06.10_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_16.06.10_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 7,
#               u'nb_filter': 128,
#               u'nb_row': 7,
#               u'subsample': [2, 2]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-21_16.30.22_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_16.30.22_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 3,
#               u'nb_filter': 64,
#               u'nb_row': 3,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-21_17.14.44_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_17.14.44_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 3,
#               u'nb_filter': 64,
#               u'nb_row': 3,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-21_17.30.13_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_17.30.13_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 3,
#               u'nb_filter': 64,
#               u'nb_row': 3,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-21_18.11.58_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_18.11.58_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 3,
#               u'nb_filter': 64,
#               u'nb_row': 3,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-21_19.11.32_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_19.11.32_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 3,
#               u'nb_filter': 64,
#               u'nb_row': 3,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-21_20.16.13_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_20.16.13_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 3,
#               u'nb_filter': 64,
#               u'nb_row': 3,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
# weights loaded from before
data = plot(project_path + 'results/2015-10-21_20.56.49_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_20.56.49_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 3,
#               u'nb_filter': 64,
#               u'nb_row': 3,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...

# %%
data = plot(project_path + 'results/2015-10-21_21.46.47_vgg_history.json')

# %%
show_arch(project_path + 'results/2015-10-21_21.46.47_vgg_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'glorot_uniform',
#               u'input_shape': [3, 180, 240],
#               u'name': u'Convolution2D',
#               u'nb_col': 7,
#               u'nb_filter': 96,
#               u'nb_row': 7,
#               u'subsample': [2, 2]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'alpha': 0.0005,
#               u'beta': 0.75,
#               u'k': 2,
#               u'n': 5,
# ...

# %%
# batch normalization
data = plot(project_path + 'results/2015-10-22_10.59.42_history.json')

# %%
show_arch(project_path + 'results/2015-10-22_10.59.42_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 3,
#               u'nb_filter': 64,
#               u'nb_row': 3,
#               u'subsample': [1, 1]},
#              {u'epsilon': 1e-06,
#               u'mode': 0,
#               u'momentum': 0.9,
#               u'name': u'BatchNormalization'},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
# ...

# %%
# no batch normalization
data = plot(project_path + 'results/2015-10-22_11.51.28_history.json')

# %%
show_arch(project_path + 'results/2015-10-22_11.51.28_architecture.json')
# Out:
# {u'class_mode': u'categorical',
#  u'layers': [{u'W_constraint': None,
#               u'W_regularizer': {u'l1': 0.0,
#                                  u'l2': 0.0005,
#                                  u'name': u'WeightRegularizer'},
#               u'activation': u'linear',
#               u'activity_regularizer': None,
#               u'b_constraint': {u'name': u'Zero'},
#               u'b_regularizer': None,
#               u'border_mode': u'valid',
#               u'init': u'he_normal',
#               u'input_shape': [3, 240, 180],
#               u'name': u'Convolution2D',
#               u'nb_col': 3,
#               u'nb_filter': 64,
#               u'nb_row': 3,
#               u'subsample': [1, 1]},
#              {u'activation': u'relu',
#               u'beta': 0.1,
#               u'name': u'Activation',
#               u'target': 0},
#              {u'ignore_border': True,
#               u'name': u'MaxPooling2D',
#               u'pool_size': [2, 2],
# ...
